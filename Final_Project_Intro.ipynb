# %% [markdown]
# ## 1. Introduction/Business Problem
#
#
# Travelers nowadays are constantly trying to find destinations that offer high quality food and drink for a fair price. Businesses also have to keep track of their neighborhood in order to understand their competitors and make strategic location decisions.
#
# In this project, I'll try to check if its possible to cluster the neighborhoods in three of the most popular US destinations by taking into account the quality and cost of the venues located per neighborhood. The main objective of this analysis is to **determine the areas in the selected destinations that would be a good option for visitors looking for _cheap, high quality eating and drinking_.** A secondary objective is to offer an overview of the competition to the business owners in their same neighborhood.

# %% [markdown]
# ## 2. Data
#
# For this project, I'll use the Foursquare API and a dataset with all US zipcodes downloaded from the [simplemaps website](https://simplemaps.com/data/us-zips).

# %% [markdown]
# I'll split the selected destinations based on the zip codes provided in the zip code dataset and I'll obtain the data related to the trending venues per neighborhood, the rating obtained by each venue and the "price" category it belongs to from the Foursquare API.

# %% [markdown]
# ### 2.1 Foursquare API
#
# The Foursquare API is a good source for information on popular venues per location.

# %%
import pandas as pd
import requests
import json
from pandas.io.json import json_normalize

# %% [markdown]
# To get the venues around an specific area, we use the "search" end point and provide the latitude and longitude of the specific location. Let's say we decide to get the venues around an specific zipcode, this is how it would work:

# %%
CLIENT_ID='AEO45ABRSDOJNO0RZOSZHLORAT5U52BBC1FNH0OEVZSX5UXP'
CLIENT_SECRET='VDWRYWJIWT3UH4JOA0SACQXRP322BBQUQWKL5TDZXHSBE5VP'
latitude=42.3577
longitude=-71.0651
VERSION='20180604'
radius=200
LIMIT='50'

# %%
url = 'https://api.foursquare.com/v2/venues/explore?client_id={}&client_secret={}&ll={},{}&v={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, radius, LIMIT)
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5ce1e0b69fb6b775bb907f7f'},
#  'response': {'suggestedFilters': {'header': 'Tap to show:',
#    'filters': [{'name': 'Open now', 'key': 'openNow'}]},
#   'headerLocation': 'Beacon Hill',
#   'headerFullLocation': 'Beacon Hill, Boston',
#   'headerLocationGranularity': 'neighborhood',
#   'totalResults': 9,
#   'suggestedBounds': {'ne': {'lat': 42.3595000018, 'lng': -71.06266866662793},
#    'sw': {'lat': 42.3558999982, 'lng': -71.06753133337207}},
#   'groups': [{'type': 'Recommended Places',
#     'name': 'recommended',
#     'items': [{'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4a549cd9f964a5202ab31fe3',
#        'name': 'Frog Pond',
#        'location': {'address': '84 Beacon St',
#         'crossStreet': 'at Boston Common',
#         'lat': 42.35613375967781,
#         'lng': -71.06567233800888,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.35613375967781,
#           'lng': -71.06567233800888}],
#         'distance': 180,
#         'postalCode': '02108',
#         'cc': 'US',
#         'city': 'Boston',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['84 Beacon St (at Boston Common)',
#          'Boston, MA 02108',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d161941735',
#          'name': 'Lake',
#          'pluralName': 'Lakes',
#          'shortName': 'Lake',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/lake_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4a549cd9f964a5202ab31fe3-0'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '3fd66200f964a5203eec1ee3',
#        'name': 'No. 9 Park',
#        'location': {'address': '9 Park St',
#         'crossStreet': 'at Beacon St.',
#         'lat': 42.35754020221547,
#         'lng': -71.06319344448555,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.35754020221547,
#           'lng': -71.06319344448555}],
#         'distance': 157,
#         'postalCode': '02108',
#         'cc': 'US',
#         'city': 'Boston',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['9 Park St (at Beacon St.)',
#          'Boston, MA 02108',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d10c941735',
#          'name': 'French Restaurant',
#          'pluralName': 'French Restaurants',
#          'shortName': 'French',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/french_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-3fd66200f964a5203eec1ee3-1'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '40b28c80f964a52098f71ee3',
#        'name': 'Union Club of Boston',
#        'location': {'address': '8 Park St',
#         'lat': 42.35741149126363,
#         'lng': -71.06270210930565,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.35741149126363,
#           'lng': -71.06270210930565}],
#         'distance': 199,
#         'postalCode': '02108',
#         'cc': 'US',
#         'city': 'Boston',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['8 Park St',
#          'Boston, MA 02108',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1c4941735',
#          'name': 'Restaurant',
#          'pluralName': 'Restaurants',
#          'shortName': 'Restaurant',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/default_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-40b28c80f964a52098f71ee3-2'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bd0a43acaff9521813ecff0',
#        'name': 'Tadpole Playground',
#        'location': {'lat': 42.35612689028739,
#         'lng': -71.06472423103777,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.35612689028739,
#           'lng': -71.06472423103777}],
#         'distance': 177,
#         'postalCode': '02108',
#         'cc': 'US',
#         'city': 'Boston',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['Boston, MA 02108', 'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1e7941735',
#          'name': 'Playground',
#          'pluralName': 'Playgrounds',
#          'shortName': 'Playground',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/playground_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bd0a43acaff9521813ecff0-3'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4dfa075f63652db0f51908dd',
#        'name': 'Nichols House Museum',
#        'location': {'address': '55 Mount Vernon St',
#         'crossStreet': 'btwn Walnut & Joy',
#         'lat': 42.358341568622215,
#         'lng': -71.06601871252427,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.358341568622215,
#           'lng': -71.06601871252427}],
#         'distance': 103,
#         'postalCode': '02108',
#         'cc': 'US',
#         'city': 'Boston',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['55 Mount Vernon St (btwn Walnut & Joy)',
#          'Boston, MA 02108',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d181941735',
#          'name': 'Museum',
#          'pluralName': 'Museums',
#          'shortName': 'Museum',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/arts_entertainment/museum_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []},
#        'venuePage': {'id': '54442002'}},
#       'referralId': 'e-0-4dfa075f63652db0f51908dd-4'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4babee0ff964a52063d63ae3',
#        'name': 'Beacon Hill Capital Market',
#        'location': {'address': '32 Myrtle St',
#         'lat': 42.35932827314974,
#         'lng': -71.0656542065004,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.35932827314974,
#           'lng': -71.0656542065004}],
#         'distance': 186,
#         'postalCode': '02114',
#         'cc': 'US',
#         'city': 'Boston',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['32 Myrtle St',
#          'Boston, MA 02114',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1f9941735',
#          'name': 'Food & Drink Shop',
#          'pluralName': 'Food & Drink Shops',
#          'shortName': 'Food & Drink',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/foodanddrink_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4babee0ff964a52063d63ae3-5'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4d9f3ad18ef3a14380968e10',
#        'name': 'Robert Gould Shaw Memorial',
#        'location': {'address': 'Beacon St',
#         'crossStreet': 'at Park St',
#         'lat': 42.35758917357506,
#         'lng': -71.06352952060391,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.35758917357506,
#           'lng': -71.06352952060391}],
#         'distance': 129,
#         'postalCode': '02108',
#         'cc': 'US',
#         'city': 'Boston',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['Beacon St (at Park St)',
#          'Boston, MA 02108',
#          'United States']},
#        'categories': [{'id': '52e81612bcbc57f1066b79ed',
#          'name': 'Outdoor Sculpture',
#          'pluralName': 'Outdoor Sculptures',
#          'shortName': 'Outdoor Sculpture',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/sculpture_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4d9f3ad18ef3a14380968e10-6'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4bdb65f963c5c9b6dfc92768',
#        'name': 'Somerset Club',
#        'location': {'address': '48 Beacon St',
#         'lat': 42.35681079283094,
#         'lng': -71.06660819494698,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.35681079283094,
#           'lng': -71.06660819494698}],
#         'distance': 158,
#         'postalCode': '02108',
#         'cc': 'US',
#         'city': 'Boston',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['48 Beacon St',
#          'Boston, MA 02108',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1d4941735',
#          'name': 'Speakeasy',
#          'pluralName': 'Speakeasies',
#          'shortName': 'Speakeasy',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/nightlife/secretbar_',
#           'suffix': '.png'},
#          'primary': True}],
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4bdb65f963c5c9b6dfc92768-7'},
#      {'reasons': {'count': 0,
#        'items': [{'summary': 'This spot is popular',
#          'type': 'general',
#          'reasonName': 'globalInteractionReason'}]},
#       'venue': {'id': '4aa91a1af964a520fe5120e3',
#        'name': "Primo's Restaurant",
#        'location': {'address': '28 Myrtle St',
#         'lat': 42.359323739960345,
#         'lng': -71.06558279269184,
#         'labeledLatLngs': [{'label': 'display',
#           'lat': 42.359323739960345,
#           'lng': -71.06558279269184}],
#         'distance': 185,
#         'postalCode': '02114',
#         'cc': 'US',
#         'city': 'Boston',
#         'state': 'MA',
#         'country': 'United States',
#         'formattedAddress': ['28 Myrtle St',
#          'Boston, MA 02114',
#          'United States']},
#        'categories': [{'id': '4bf58dd8d48988d1ca941735',
#          'name': 'Pizza Place',
#          'pluralName': 'Pizza Places',
#          'shortName': 'Pizza',
#          'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/pizza_',
#           'suffix': '.png'},
#          'primary': True}],
#        'delivery': {'id': '55345',
#         'url': 'https://www.grubhub.com/restaurant/primos-pizza-28-myrtle-st-beacon-hill/55345?affiliate=1131&utm_source=foursquare-affiliate-network&utm_medium=affiliate&utm_campaign=1131&utm_content=55345',
#         'provider': {'name': 'grubhub',
#          'icon': {'prefix': 'https://fastly.4sqi.net/img/general/cap/',
#           'sizes': [40, 50],
#           'name': '/delivery_provider_grubhub_20180129.png'}}},
#        'photos': {'count': 0, 'groups': []}},
#       'referralId': 'e-0-4aa91a1af964a520fe5120e3-8'}]}]}}

# %%
#get relevant information from JSON
info=results['response']['groups'][0]['items']
info[0]
# Out:
# {'reasons': {'count': 0,
#   'items': [{'summary': 'This spot is popular',
#     'type': 'general',
#     'reasonName': 'globalInteractionReason'}]},
#  'venue': {'id': '4a549cd9f964a5202ab31fe3',
#   'name': 'Frog Pond',
#   'location': {'address': '84 Beacon St',
#    'crossStreet': 'at Boston Common',
#    'lat': 42.35613375967781,
#    'lng': -71.06567233800888,
#    'labeledLatLngs': [{'label': 'display',
#      'lat': 42.35613375967781,
#      'lng': -71.06567233800888}],
#    'distance': 180,
#    'postalCode': '02108',
#    'cc': 'US',
#    'city': 'Boston',
#    'state': 'MA',
#    'country': 'United States',
#    'formattedAddress': ['84 Beacon St (at Boston Common)',
#     'Boston, MA 02108',
#     'United States']},
#   'categories': [{'id': '4bf58dd8d48988d161941735',
#     'name': 'Lake',
#     'pluralName': 'Lakes',
#     'shortName': 'Lake',
#     'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/parks_outdoors/lake_',
#      'suffix': '.png'},
#     'primary': True}],
#   'photos': {'count': 0, 'groups': []}},
#  'referralId': 'e-0-4a549cd9f964a5202ab31fe3-0'}

# %% [markdown]
# Turn info into a dataframe (using the code from one of the labs in the course)

# %%
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# %%
df = json_normalize(info) # flatten JSON

# filter columns
filtered_columns = ['venue.name', 'venue.categories'] + [col for col in df.columns if col.startswith('venue.location.')] + ['venue.id']
df_filtered = df.loc[:, filtered_columns]

# filter the category for each row
df_filtered['venue.categories'] = df_filtered.apply(get_category_type, axis=1)

# clean columns
df_filtered.columns = [col.split('.')[-1] for col in df_filtered.columns]

df_filtered.head()
# Out:
#                    name         categories             address  cc    city  \
# 0             Frog Pond               Lake        84 Beacon St  US  Boston
# 1            No. 9 Park  French Restaurant           9 Park St  US  Boston
# 2  Union Club of Boston         Restaurant           8 Park St  US  Boston
# 3    Tadpole Playground         Playground                 NaN  US  Boston
# 4  Nichols House Museum             Museum  55 Mount Vernon St  US  Boston
#
#          country        crossStreet  distance  \
# 0  United States   at Boston Common       180
# 1  United States      at Beacon St.       157
# 2  United States                NaN       199
# 3  United States                NaN       177
# 4  United States  btwn Walnut & Joy       103
#
#                                     formattedAddress  \
# 0  [84 Beacon St (at Boston Common), Boston, MA 0...
# 1  [9 Park St (at Beacon St.), Boston, MA 02108, ...
# 2       [8 Park St, Boston, MA 02108, United States]
# 3                  [Boston, MA 02108, United States]
# 4  [55 Mount Vernon St (btwn Walnut & Joy), Bosto...
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 42.35613375967781...  42.356134 -71.065672
# 1  [{'label': 'display', 'lat': 42.35754020221547...  42.357540 -71.063193
# 2  [{'label': 'display', 'lat': 42.35741149126363...  42.357411 -71.062702
# 3  [{'label': 'display', 'lat': 42.35612689028739...  42.356127 -71.064724
# 4  [{'label': 'display', 'lat': 42.35834156862221...  42.358342 -71.066019
#
#   postalCode state                        id
# 0      02108    MA  4a549cd9f964a5202ab31fe3
# 1      02108    MA  3fd66200f964a5203eec1ee3
# 2      02108    MA  40b28c80f964a52098f71ee3
# 3      02108    MA  4bd0a43acaff9521813ecff0
# 4      02108    MA  4dfa075f63652db0f51908dd

# %% [markdown]
# I can get the venues ratings using the venues ids and getting it from the API

# %%
venues_ids=df_filtered['id']
venues_ids
# Out:
# 0    4a549cd9f964a5202ab31fe3
# 1    3fd66200f964a5203eec1ee3
# 2    40b28c80f964a52098f71ee3
# 3    4bd0a43acaff9521813ecff0
# 4    4dfa075f63652db0f51908dd
# 5    4babee0ff964a52063d63ae3
# 6    4d9f3ad18ef3a14380968e10
# 7    4bdb65f963c5c9b6dfc92768
# 8    4aa91a1af964a520fe5120e3
# Name: id, dtype: object

# %%
df_filtered['rating']=0

# %%
venue_id='4a549cd9f964a5202ab31fe3'
url='https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
result = requests.get(url).json()
result
# Out:
# {'meta': {'code': 429,
#   'errorType': 'quota_exceeded',
#   'errorDetail': 'Quota exceeded',
#   'requestId': '5ce1e2f94c1f6753b66f05f8'},
#  'response': {}}

# %%
for venue_id, i in zip(venues_ids,range(0,len(venues_ids))):
    url='https://api.foursquare.com/v2/venues/{}?client_id={}&client_secret={}&v={}'.format(venue_id, CLIENT_ID, CLIENT_SECRET, VERSION)
    result = requests.get(url).json()
    df_filtered['rating'].loc[i]=result['response']['venue']['rating']
    try:
        print(result['response']['venue']['rating'])
    except:
        print('This venue has not been rated yet.')

# %%
df_filtered
# Out:
#                          name         categories             address  cc  \
# 0                   Frog Pond               Lake        84 Beacon St  US
# 1                  No. 9 Park  French Restaurant           9 Park St  US
# 2        Union Club of Boston         Restaurant           8 Park St  US
# 3          Tadpole Playground         Playground                 NaN  US
# 4        Nichols House Museum             Museum  55 Mount Vernon St  US
# 5  Beacon Hill Capital Market  Food & Drink Shop        32 Myrtle St  US
# 6  Robert Gould Shaw Memorial  Outdoor Sculpture           Beacon St  US
# 7               Somerset Club          Speakeasy        48 Beacon St  US
# 8          Primo's Restaurant        Pizza Place        28 Myrtle St  US
#
#      city        country        crossStreet  distance  \
# 0  Boston  United States   at Boston Common       180
# 1  Boston  United States      at Beacon St.       157
# 2  Boston  United States                NaN       199
# 3  Boston  United States                NaN       177
# 4  Boston  United States  btwn Walnut & Joy       103
# 5  Boston  United States                NaN       186
# 6  Boston  United States         at Park St       129
# 7  Boston  United States                NaN       158
# 8  Boston  United States                NaN       185
#
#                                     formattedAddress  \
# 0  [84 Beacon St (at Boston Common), Boston, MA 0...
# 1  [9 Park St (at Beacon St.), Boston, MA 02108, ...
# 2       [8 Park St, Boston, MA 02108, United States]
# 3                  [Boston, MA 02108, United States]
# 4  [55 Mount Vernon St (btwn Walnut & Joy), Bosto...
# 5    [32 Myrtle St, Boston, MA 02114, United States]
# 6  [Beacon St (at Park St), Boston, MA 02108, Uni...
# 7    [48 Beacon St, Boston, MA 02108, United States]
# 8    [28 Myrtle St, Boston, MA 02114, United States]
#
#                                       labeledLatLngs        lat        lng  \
# 0  [{'label': 'display', 'lat': 42.35613375967781...  42.356134 -71.065672
# 1  [{'label': 'display', 'lat': 42.35754020221547...  42.357540 -71.063193
# 2  [{'label': 'display', 'lat': 42.35741149126363...  42.357411 -71.062702
# 3  [{'label': 'display', 'lat': 42.35612689028739...  42.356127 -71.064724
# 4  [{'label': 'display', 'lat': 42.35834156862221...  42.358342 -71.066019
# 5  [{'label': 'display', 'lat': 42.35932827314974...  42.359328 -71.065654
# 6  [{'label': 'display', 'lat': 42.35758917357506...  42.357589 -71.063530
# 7  [{'label': 'display', 'lat': 42.35681079283094...  42.356811 -71.066608
# 8  [{'label': 'display', 'lat': 42.35932373996034...  42.359324 -71.065583
#
#   postalCode state                        id  rating
# 0      02108    MA  4a549cd9f964a5202ab31fe3       0
# 1      02108    MA  3fd66200f964a5203eec1ee3       1
# 2      02108    MA  40b28c80f964a52098f71ee3       2
# 3      02108    MA  4bd0a43acaff9521813ecff0       3
# 4      02108    MA  4dfa075f63652db0f51908dd       4
# 5      02114    MA  4babee0ff964a52063d63ae3       5
# 6      02108    MA  4d9f3ad18ef3a14380968e10       6
# 7      02108    MA  4bdb65f963c5c9b6dfc92768       7
# 8      02114    MA  4aa91a1af964a520fe5120e3       8

# %% [markdown]
# After that, we only need to repeat this for all neighborhoods and apply the clustering to find if it is possible to say which neighborhoods are a "cheap-high quality" option for the visitors.

# %% [markdown]
# ### 2.2 US zip codes dataset
#
# Here is how the US zip code dataset looks like.
#
#
# In order to use the dataset, I downloaded it as a csv file into my computer from [this link](https://simplemaps.com/data/us-zips).

# %%
path='/Users/nicolecapriles/Desktop/uszips.csv'
zipcodes=pd.read_csv(path)

# %% [markdown]
# The dataset contains the zip codes for all states in the US, their longitude and latitude and some other information. Check the headers below

# %%
zipcodes.head()
# Out:
#    zip      lat      lng       city state_id   state_name  zcta  parent_zcta  \
# 0  601  18.1800 -66.7522   Adjuntas       PR  Puerto Rico  True          NaN
# 1  602  18.3607 -67.1752     Aguada       PR  Puerto Rico  True          NaN
# 2  603  18.4544 -67.1220  Aguadilla       PR  Puerto Rico  True          NaN
# 3  606  18.1672 -66.9383    Maricao       PR  Puerto Rico  True          NaN
# 4  610  18.2903 -67.1224     Anasco       PR  Puerto Rico  True          NaN
#
#    population  density  county_fips county_name  \
# 0       18570    111.4        72001    Adjuntas
# 1       41520    523.7        72003      Aguada
# 2       54689    667.9        72005   Aguadilla
# 3        6615     60.4        72093     Maricao
# 4       29016    311.9        72011      Añasco
#
#                           all_county_weights  imprecise  military  \
# 0               {'72001':99.43,'72141':0.57}      False     False
# 1                              {'72003':100}      False     False
# 2                              {'72005':100}      False     False
# 3  {'72093':94.88,'72121':1.35,'72153':3.78}      False     False
# 4               {'72003':0.55,'72011':99.45}      False     False
#
#               timezone
# 0  America/Puerto_Rico
# 1  America/Puerto_Rico
# 2  America/Puerto_Rico
# 3  America/Puerto_Rico
# 4  America/Puerto_Rico

# %% [markdown]
# I'll only need the zip code, latitude, longitude city and state. So we can drop all other columns in the dataframe.

# %%
columns_drop=['zcta','parent_zcta','population','density','county_fips','county_name','all_county_weights','imprecise','military','timezone']
zipcodes.drop(columns_drop,axis=1,inplace=True)

# %%
zipcodes.head()
# Out:
#    zip      lat      lng       city state_id   state_name
# 0  601  18.1800 -66.7522   Adjuntas       PR  Puerto Rico
# 1  602  18.3607 -67.1752     Aguada       PR  Puerto Rico
# 2  603  18.4544 -67.1220  Aguadilla       PR  Puerto Rico
# 3  606  18.1672 -66.9383    Maricao       PR  Puerto Rico
# 4  610  18.2903 -67.1224     Anasco       PR  Puerto Rico

# %% [markdown]
# Since I'll run the project with three specific destinations (Boston, DC and New York City), we can split this dataset to obtain the zipcodes per city.

# %%
Boston_zipcodes=zipcodes[(zipcodes['state_id']=='MA')&(zipcodes['city']=='Boston')]
DC_zipcodes=zipcodes[(zipcodes['state_id']=='DC')&(zipcodes['city']=='Washington')]
NYC_zipcodes=zipcodes[(zipcodes['state_id']=='NY')&(zipcodes['city']=='New York')]

# %%
Boston_zipcodes
# Out:
#       zip      lat      lng    city state_id     state_name
# 462  2108  42.3577 -71.0651  Boston       MA  Massachusetts
# 463  2109  42.3648 -71.0530  Boston       MA  Massachusetts
# 464  2110  42.3583 -71.0518  Boston       MA  Massachusetts
# 465  2111  42.3501 -71.0591  Boston       MA  Massachusetts
# 466  2113  42.3653 -71.0553  Boston       MA  Massachusetts
# 467  2114  42.3632 -71.0673  Boston       MA  Massachusetts
# 468  2115  42.3410 -71.0946  Boston       MA  Massachusetts
# 469  2116  42.3505 -71.0756  Boston       MA  Massachusetts
# 470  2118  42.3382 -71.0708  Boston       MA  Massachusetts
# 501  2163  42.3663 -71.1209  Boston       MA  Massachusetts
# 513  2199  42.3475 -71.0820  Boston       MA  Massachusetts
# 514  2203  42.3605 -71.0589  Boston       MA  Massachusetts
# 515  2210  42.3478 -71.0390  Boston       MA  Massachusetts
# 516  2215  42.3478 -71.1030  Boston       MA  Massachusetts

# %% [markdown]
# These three datasets will be the group of zipcodes I'll use to obtain the venues from the Foursquare API.
